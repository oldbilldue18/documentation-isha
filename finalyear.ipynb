# %% [markdown]
# <a href="https://colab.research.google.com/github/oldbilldue18/documentation-isha/blob/main/finalyear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install YOLOv8 and Roboflow
# !pip install ultralytics roboflow --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 81.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 116.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="r8Q9O0CWEfBJUytqlIrg")
project = rf.workspace("weed25-dataset").project("weed25-labeling")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to weed25-labeling-4 in yolov8:: 100%|██████████| 19115/19115 [00:03<00:00, 5864.40it/s]

# %%
# !pip install ultralytics --quiet

# %%
from ultralytics import YOLO

# Load YOLOv8 medium model (you can use 'yolov8s.pt' or 'yolov8n.pt' if you want faster training)
model = YOLO("yolov8m.pt")

# %%
print(dataset.location)
# Out:
# /content/weed25-labeling-4

# %%
model.train(
    data="/content/weed25-labeling-4/data.yaml",
    epochs=5,
    imgsz=640,
    batch=16,
    name="weed-rice-yolov8m"
)
# Out:
# Ultralytics 8.3.174 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image, display

# Replace with your actual path
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/results.png'))

# %%
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/confusion_matrix.png'))

# %%
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/labels.jpg'))

# %%
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/BoxP_curve.png'))
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/BoxPR_curve.png'))
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/BoxR_curve.png'))
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/BoxF1_curve.png'))

# %%
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/val_batch0_labels.jpg'))

# %%
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/val_batch1_labels.jpg'))

# %%
display(Image('/content/sample_data/detect/weed-rice-yolov8m2/val_batch2_labels.jpg'))

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('/content/sample_data/detect/weed-rice-yolov8m2/weights/best.pt')


results = model('/content/weed25-labeling-4/valid/images/IMG_20160626_161630_jpg.rf.57d961d97080175df98dd7aa5b30ed6d.jpg')

results[0].show()
# Out:
# image 1/1 /content/weed25-labeling-4/valid/images/IMG_20160626_161630_jpg.rf.57d961d97080175df98dd7aa5b30ed6d.jpg: 640x640 1 goosefoots, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
model = YOLO('/content/sample_data/detect/weed-rice-yolov8m2/weights/best.pt')


results = model('all-about-rice.jpg')

results[0].show()
# Out:
# image 1/1 /content/all-about-rice.jpg: 352x640 (no detections), 45.2ms
# Speed: 2.2ms preprocess, 45.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# <PIL.Image.Image image mode=RGB size=1200x642>

# %%
# !git config --global user.name "hricha_11"

# %%
# !git config --global user.email "hrichamehra11@gmail..com"
